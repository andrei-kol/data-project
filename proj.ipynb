# %% [markdown]
# <font color='DarkBlue' size=+2><b>Комментарий ревьюера</b></font><br>
# <font color='DarkBlue'>Привет, Андрей! <br>Меня зовут Олег Мазуренко, и я буду проверять этот проект. Спасибо за проделанную работу! <br>Ко мне можно обращаться на «ты». Как мне обращаться, напиши.</font><br>
# <font color='DarkBlue'>Я буду использовать различные цвета, чтобы было удобнее воспринимать мои комментарии:</font><br>
# <font color='DarkBlue'>Синий текст &mdash; просто текст комментария.</font><br>
# <font color='DarkGreen'>👌 Зеленый текст &mdash; все отлично.</font><br>
# <font color='DarkMagenta'>👉 Фиолетовый текст &mdash; сделано все правильно, однако есть рекомендации, на что стоит обратить внимание. Реализованные рекомендации позволят нам наработать опыт решения задачи разными способами или посмотреть на задачу под иным углом.</font><br>
# <font color='Red'>🛠 Красный текст &mdash; есть недочеты, они иногда бывают. </font><br><font color='DarkBlue'>Любая ошибка это возможность посмотреть на задачу с другой стороны и освоить новые знания, по этому не надо расстраиваться, если они есть.</font><br>
# <font color='DarkBlue'>Обращаю внимание, что комментарии ревьюера после проверки удалять нельзя они помогают отследить логику исправления или изменения проекта. Это дополнительный навык при обучении. Свой исправляемый код лучше тоже не удалять, а ремить #, это позволит акцентировать изменения в ходе подготовки окончательного варианта проекта.<br>
# Ответы на мои комментарии лучше тоже помечать.
# Например: </font><font color='Blue'><b>Комментарий студента</b></font><br>
# <font color='DarkBlue'><b>Теперь посмотрим, что получилось!</b></font>

# %% [markdown]
# ## Исследование данных о российском кинопрокате

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Любой проект, как учебный, так и реальный, начинается с его описания, содержащего: описание контекста, цель и краткий план исследования. Надо его написать. Просто задание проекта изложить своими словами.</font>

# %% [markdown]
# Данное исследование выполнено по заказу Министерства культуры Российской Федерации. Его цель — изучить рынок российского кинопроката, выявить текущие тенденции и проанализировать фильмы, получившие государственное финансирование.
#
# Работа опирается на данные, опубликованные на портале открытых данных Министерства культуры. В них содержится информация о прокатных удостоверениях, кассовых сборах, государственной поддержке и рейтингах фильмов с сайта “КиноПоиск”.
#
# Исследование будет включать:
#
# 	1.	Анализ динамики выхода фильмов в прокат по годам, определение полноты представленных данных и выявление изменений в популярности кинопроката.
# 	2.	Выявление минимальных и максимальных кассовых сборов по годам и расчет средних значений, чтобы понять, как менялись доходы индустрии.
# 	3.	Оценку влияния возрастных ограничений на кассовые сборы фильмов в период с 2015 по 2019 год, чтобы определить предпочтения различных групп зрителей.
#
#
# Результаты исследования помогут Министерству культуры лучше понять рынок кинопроката и оптимизировать подходы к государственной поддержке, обеспечив развитие индустрии и удовлетворение запросов зрителей.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkGreen'>👌 Все проекты, это как часть реального исследования, за которое деньги заплатят или не заплатят. <br>А отчет читают: сначала описание, о чем идет речь и что делаем, потом выводы: что в итоге получили. А когда у заказчика в голове все сложилось, то смотрят как это делалось. То есть, в описании необходимо отразить какая цель исследования, какой контекст (особенности отрасли и данных), что планируем делать (план исследования). <br>И в реальном проекте не будет инструкции и задач, которые необходимо выполнить, по этому следует научиться делать описание проекта самостоятельно.</font>

# %% [markdown]
# ### Шаг 1. Откройте файлы с данными и объедините их в один датафрейм.
#
# Объедините данные таким образом, чтобы все объекты из датасета `mkrf_movies` обязательно вошли в получившийся датафрейм.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_0" aria-expanded="false" aria-controls="collapseHint_0">Подсказка</button>
#         </div>
#         <div id="collapseHint_0" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Обратите внимание на тип данных столбца, по которому будете соединять датафреймы. Тип данных этих столбцов должен быть одинаковым в обоих датафреймах.
#             </div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# Импорт библиотек

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Сохраним данные из файлов, посмотрим, какие в них данные.

# %%
#Для удобства восприятия чисел, настроим формат отображения:
pd.set_option('display.float_format', '{:.2f}'.format)

#данные о прокатных удостоверениях. 
data1 = pd.read_csv('/datasets/mkrf_movies.csv')
display(data1.head(2))
data1.info()


#данные о прокате в российских кинотеатрах. 
data2 = pd.read_csv('/datasets/mkrf_shows.csv')
display(data2.head(1))
data2.info()
# Out:
#                   title   puNumber           show_start_date            type  \
# 0      Открытый простор  221048915  2015-11-27T12:00:00.000Z  Художественный
# 1  Особо важное задание  111013716  2016-09-13T12:00:00.000Z  Художественный
#
#                                          film_studio production_country  \
# 0  Тачстоун Пикчерз, Кобальт Пикчерз, Бикон Пикче...                США
# 1                              Киностудия "Мосфильм"               СССР
#
#         director                                   producer  \
# 0  Кевин Костнер  Дэвид Валдес, Кевин Костнер, Джейк Эбертс
# 1      Е.Матвеев                                        NaN
#
#                  age_restriction  refundable_support  nonrefundable_support  \
# 0    «18+» - запрещено для детей                 NaN                    NaN
# 1  «6+» - для детей старше 6 лет                 NaN                    NaN
#
#    budget financing_source ratings                  genres
# ...

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Правильно, что избавились от экспоненциального формата вывода чисел.</font><br>
# <font color='DarkGreen'>👌 Хорошо, исследовали общую информацию о датасетах.</font>

# %% [markdown]
# Заметим, что данные связаны между собой, поэтому можно совместить данные в один дата фрейм.
# Вначале приведем столбец, по которому будем соединять, к единому типу данных.

# %%
data2['puNumber'] = data2['puNumber'].astype('str')

data = data1.merge(
    data2,
    on = 'puNumber',
    how = 'left',
    suffixes = ('_первый', '_второй'))

# %%
#Посмотрим, что получилось
display(data.head())

display(data['box_office'].isna().sum()) #посмотрим, сколько данных в столбце 'box_office' не хватает.
# Out:
#                   title   puNumber           show_start_date            type  \
# 0      Открытый простор  221048915  2015-11-27T12:00:00.000Z  Художественный
# 1  Особо важное задание  111013716  2016-09-13T12:00:00.000Z  Художественный
# 2          Особо опасен  221038416  2016-10-10T12:00:00.000Z  Художественный
# 3          Особо опасен  221026916  2016-06-10T12:00:00.000Z  Художественный
# 4          Особо опасен  221030815  2015-07-29T12:00:00.000Z  Художественный
#
#                                          film_studio production_country  \
# 0  Тачстоун Пикчерз, Кобальт Пикчерз, Бикон Пикче...                США
# 1                              Киностудия "Мосфильм"               СССР
# 2  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 3  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 4  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
#
# ...

# %% [markdown]
# Мы импортировали две основные библиотеки - pandas, matplotlib.
#
# Прочитали и сохранили два .csv файла, объеденив их в один.
#
# Во втором файле хранилось 7486 строк , а во втором - 3158.
# После соединения двух сетов данных получилося датафрейм с 15ью столбцами.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, объединили таблицы, ни чего не потеряли и сделали выводы.</font>

# %% [markdown]
# ### Шаг 2. Предобработка данных

# %% [markdown]
# #### Шаг 2.1. Проверьте типы данных
#
# - Проверьте типы данных в датафрейме и преобразуйте их там, где это необходимо.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7486 entries, 0 to 7485
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7486 non-null   object
#  2   show_start_date        7486 non-null   object
#  3   type                   7486 non-null   object
#  4   film_studio            7468 non-null   object
#  5   production_country     7484 non-null   object
#  6   director               7477 non-null   object
#  7   producer               6918 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   object
# ...

# %% [markdown]
# Самыми очевидными проблемами с типами данных являются следующие столбцы:
#
# - **show_start_date** следует перевести в формат datetime.
#
# - **ratings** следует перевести в числовой формат.

# %%
#Преобразуем смешанный тип данных object в формат данных datetime.
data['show_start_date'] = pd.to_datetime(data['show_start_date'], format = '%Y-%m-%dT%H:%M:%S.%fZ')


#Для удобства анализа уберем данные о времени, оставим только дату. 
#Однако данный метод преобразует данные в строчный тип данных. 
data['show_start_date'] = data['show_start_date'].dt.strftime('%Y-%m-%d')

#Возвращаем тип данных обратно в datetime/
data['show_start_date'] = pd.to_datetime(data['show_start_date'], format = '%Y-%m-%d')

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, преобразовали колонку `show_start_date` в дату.</font>

# %%
#Так как при преобразовании типа данных для столбца 'ratings' возникает ошибка, посмотрим, какие значения могут встречаться.
data['ratings'].value_counts()

#Видно, что присутсвуют значения вида "__%". Вероятно, была допущена ошибка, таких значений немного. 
#Приведем данные к единому формату, после чего - преобразуем тип данных к "float".

#Создаем функцию, которая переведет формат из "n%" в "n/10".
def procent(row):
    if isinstance(row, str) and '%' in row:
        row = row.replace('%', '')
        row = float(row)
        row = row/10
    return row

#Применим к столбцу "ratings". Изменим тип данных во всем столбце на "float".   
data['ratings'] = data['ratings'].apply(procent)

data['ratings'] = data['ratings'].astype('float')

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Как-то сложно делаем замену, можно вот так:</font><br>
# `data['ratings'] = data['ratings'].str.replace('%', '').astype('float').apply(lambda x: x/10 if x>10 else x)`

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 В принципе  такое преобразование возможно. Только надо иметь ввиду, что полученные данные коррелируют с рейтингом на сайте Кинопоиск, но не равны ему (по данным 2019 года). В чем можно убедиться, проверив несколько фильмов вручную, хотя в настоящее время данные там могут не соответствовать нашему датасету.</font>

# %% [markdown]
# Дальше для оптимизиации я хочу некоторые столбцы, где мало уникальных данных, заменить на категориальный тип данных.

# %%
#Создадим словарь, где ключом будет название столбца, а кол-во уникальных значений значением, соответственно 

num_unique = {col: data[col].nunique() for col in data.columns}
display(num_unique)

#Тип данных в столбцах "type", "age_restriction", "financing_source" можно заменить на категориальный тип данных. 

data['type'] = data['type'].astype('category')
data['age_restriction'] = data['age_restriction'].astype('category')
data['financing_source'] = data['financing_source'].astype('category')

#В рейтинге тоже немного уникальных значений, однако в данном случае рейтинг - это количественная категория, поэтому оставитм как есть.
# Out:
# {'title': 6772,
#  'puNumber': 7484,
#  'show_start_date': 1965,
#  'type': 8,
#  'film_studio': 5490,
#  'production_country': 950,
#  'director': 4811,
#  'producer': 5349,
#  'age_restriction': 5,
#  'refundable_support': 34,
#  'nonrefundable_support': 75,
#  'budget': 290,
#  'financing_source': 3,
#  'ratings': 84,
#  'genres': 742,
#  'box_office': 2938}

# %% [markdown]
# **Промежуточный итог:**
# - изменили тип данных столбца "show_start_date" на datetime, для удобства оставили только дату;
# - изменил тип данных столбца "ratings" на float, так как это количественная категория;
# - изменили типы данных в столбцах "type", "age_restriction", "financing_source" на категориальный тип данных для оптимизации.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Правильно выполнено задание по переводу типов данных.</font>

# %% [markdown]
# #### Шаг 2.2. Изучите пропуски в датафрейме
#
# - Объясните, почему заполнили пропуски определённым образом или почему не стали этого делать.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Лучше перед обработкой пропусков делать контроль размера датасета до и после обработки. Примерно вот так:</font>

# %%
# Комментарий ревьюера
temp = data.copy() # создаем копию датасета до преобразования
len(temp)
# Out:
# 7486

# %% [markdown]
# Посмотрим, какое количество столбцов имеет пропуски. Также обратим внимание на отсутсвующую часть данных.

# %%
pd.DataFrame(round(data.isna().mean()*100, 1)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_8cb6c_row0_col0,#T_8cb6c_row1_col0,#T_8cb6c_row2_col0,#T_8cb6c_row3_col0,#T_8cb6c_row4_col0,#T_8cb6c_row5_col0,#T_8cb6c_row6_col0,#T_8cb6c_row8_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_8cb6c_row7_col0{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_8cb6c_row9_col0,#T_8cb6c_row10_col0,#T_8cb6c_row11_col0,#T_8cb6c_row12_col0{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_8cb6c_row13_col0,#T_8cb6c_row14_col0{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_8cb6c_row15_col0{
#             background-color:  #f2cab5;
#             color:  #000000;
#         }</style><table id="T_8cb6c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %% [markdown]
# Отдельно выделим группу столбцов, которую рассмотрим в совокупности.   - **"refundable_support", "nonrefundable_support", "budget", "financing_source"**
#
# В столбце **"box_office"** не хватает данных, так как в файле "mkrf_shows" не было данных.
#
#
# Столбцы **ratings, genres, producer** рассмотрим отдельно.

# %% [markdown]
# Обратим внимание, что все четыре столбца, которые имеют одинаковое количество пропусков, связаны с финансированием фильмов.
#
# Если проанализировать все источники финансирования, то получим следующие: **‘Министерство культуры’, ‘Фонд кино’, ‘Министерство культуры, Фонд кино’**.
#
# Поскольку данные были опубликованы на официальном сайте Министерства культуры, можно сделать логичный вывод, что
# источники финансирования были указаны именно этим министерством, и информация о других источниках отсутствует.
#
# Соответственно, для фильмов, где источниками являются Министерство культуры или Фонд кино, данные должны быть указаны, а для строк, где источники отсутствуют, можно предположить, что финансирование исходило от других источников.
#
# В связи с этим, можно заменить пропуски в столбце financing_source значением **“Unknown”** как маркер для отсутствующих данных.
#
# Что касается других столбцов, то их заполнять не стоит, поскольку, если начинать заполнять один столбец, желательно заполнить все пропуски во всех столбцах, что, например, для столбца budget не является целесообразным.

# %%
#Посмотрим источники финансирования 
display(data['financing_source'].unique())

#Заполним пропуски
data['financing_source'] = data['financing_source'].cat.add_categories('Unknown')
data['financing_source'] = data['financing_source'].fillna('Unknown')
# Out:
# [NaN, 'Министерство культуры', 'Фонд кино', 'Министерство культуры, Фонд кино']
# Categories (3, object): ['Министерство культуры', 'Фонд кино', 'Министерство культуры, Фонд кино']

# %% [markdown]
# Столбец **"producer"**

# %%
#Посчитаем общее количество пропусков для данного столбца
display(data['producer'].isna().sum()) #568

#Заметим, что данное поле часто отсутсвует для страны СССР 
display(data[(data['producer'].isna()) & (data['production_country'].str.contains('СССР', case=False))].count())

#Действительно, для 394 строк с пропуском в поле "producer", страна производитель - CCCР. 
#Посмотрим, есть ли заполненное поле продюсера со страной СССР.

display(data[(data['producer'].notna()) & (data['production_country'].str.contains('СССР', case=False))].head())

#Видим, что продюсером обычно является для фильмов, произведенных в СССР, являются либо директор, либо киностудия. 
#Думаю, что заменить пропуски в поле продюсер там, где страна CCСР, на директора будет хорошей идеей. 

data.loc[data['production_country'].str.contains('СССР', na = False), 'producer'] = data.loc[data['production_country'].str.contains('СССР', na = False), 'producer'].fillna(data['director'])

#Посмотрим, сколько осталось пропусков.
display(data['producer'].isna().sum())  #174
# Out:
# 568
# title                    394
# puNumber                 394
# show_start_date          394
# type                     394
# film_studio              394
# production_country       394
# director                 394
# producer                   0
# age_restriction          394
# refundable_support         0
# nonrefundable_support      0
# budget                     0
# financing_source         394
# ratings                  376
# genres                   376
# box_office                79
# dtype: int64
#                                            title   puNumber show_start_date  \
# 3093  Александр Невский (восстановленная версия)  111001516      2016-02-12
# 3193        Берегись автомобиля (цветная версия)  111001316      2016-02-11
# 3926                                  Сафари № 6  111001611      2011-02-17
# 3931                        Сон в красном тереме  112000311      2011-02-17
# 3962     Небесный тихоход (новая цветная версия)  111000110      2010-01-14
#
# ...

# %% [markdown]
# Мы заполнили пропуски в столбце продюсер для фильмов, произведенных в СССР. В связи с особенностями корпоративных отношений в киноиндустрии, информация о продюсере могла отсутствовать, однако роль продюсера, скорее всего, выполнял директор.
#
# Хотя оставление этих пропусков было бы возможным, я решил заполнить их, так как такая информация может оказаться полезной в дальнейшем анализе.
#
# После заполнения пропусков в столбце продюсер остались 174 строки с пустыми значениями. Причина этих пропусков остается неясной — возможно, данные были утеряны или не были заполнены на этапе формирования базы данных.

# %% [markdown]
# **Пропуски в столбцах ratings и genres  .**
#
# **Ratings** — количественный признак. Невозможно точно заменить отсутствующие значения, так как рейтинг фильма на платформе “Кинопоиск” может отсутствовать из-за малого числа оценок. Это может указывать на низкую популярность фильма. Замена пропусков на медиану не является оптимальным решением, так как рейтинг может зависеть от множества факторов, таких как страна или бюджет фильма, что может существенно повлиять на анализ.
#
# **Genres** — категориальный признак. Пропуски в этом столбце также оставляем пустыми, так как не удалось найти четких закономерностей для их заполнения. Вероятно, информация отсутствует из-за ошибок на этапе выгрузки данных или изначально была не заполнена при вводе.

# %%
display(data['ratings'].isna().sum()) #967 пропусков
#display(data[data['ratings'].isna()].head(50))

 
display(data['genres'].isna().sum()) #976 пропусков
display(data[(data['genres'].isna()) & (data['ratings'].notna())].head(10))
# Out:
# 967
# 976
#                                              title   puNumber show_start_date  \
# 1874                    Короткие истории о любви 2  121002615      2015-02-13
# 2910                                        Аномия  111005216      2016-03-11
# 3260         Сборник короткометражек Кинотавра 18+  111012916      2016-08-19
# 3434  Сборник короткого метра. Оскар. Фильмы. 2017  121004117      2017-03-03
# 3439                            Семь диких историй  126005916      2016-11-28
# 3446                  Короткие истории о любви - 4  126006316      2016-12-30
# 6779                     РУССКОЕ КРАТКОЕ. Выпуск 3  111004219      2019-03-15
# 7060                     Русское краткое. Выпуск 4  111011419      2019-07-16
# 7291                                       Курьезы  111017619      2019-10-18
#
#                  type                                        film_studio  \
# 1874   Художественный  Кавиар, Курт 13, СтритЛайт Филмз, Нэйер Дойче ...
# ...

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, сделан анализ пропусков.</font>

# %% [markdown]
# #### Шаг 2.3. Изучите дубликаты в датафрейме
# - Проверьте, есть ли в данных дубликаты. Опишите причины, которые могли повлиять на появление дублей.

# %% [markdown]
# Проверим на явные дубликаты:

# %%
display(data.duplicated().sum())
# Out:
# 0

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, что проверены явные дубликаты, иногда они сильно искажают анализ.</font>

# %% [markdown]
# Повторений целых строк в датафрейме нет.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Не проверены  неявные (неполные) дубликаты. Что в датасете должно быть уникальным? Очевидно, что номер прокатного удостоверения и название фильма.</font>

# %% [markdown]
# Проверим дубликаты в столбцах "title" и "puNumber".

# %%
display(data['title'].duplicated().sum())
display(data['puNumber'].duplicated().sum())


#удаляем дубликаты с одинаковым прокатным удостоверением.
data = data.drop_duplicates(subset=['puNumber'])

#обновим идексацию
data = data.reset_index(drop=True)


#проверим
display(data['title'].duplicated().sum())
display(data['puNumber'].duplicated().sum())


display(len(data))
# Out:
# 714
# 2
# 713
# 0
# 7484

# %% [markdown]
# Оказалось, что дубликатов названий фильмов довольно много - 714, однако удалять их не стоит. Это связано с тем, что прокатное удостоверение выдается не только на прокат в кинотеатрах, но и для разных других целей.
#
# Было обнаружено 2 дубликата номера прокатного удостоверения. Один дубликат мы все же удалим.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkMagenta'>👉 Первичный анализ данных подразумевает исследование данных на наличие ошибок и аномалий. При этом нет необходимости удалять аномалии, если они являются особенностями датасета и не мешают дальнейшему анализу. Необходимо помнить, что удаление аномалий или ошибок в одной колонке приводит к удалению значимых данных в других колонках. Если эти значимые данные являются признаками, которые необходимо в дальнейшем анализировать, то это является критической ошибкой.</font><br>
# <font color='Red'>🛠 На основании чего было принято решение об удалении строк содержащих одинаковые названия фильмов? У них разные номера прокатных удостоверений, значит они не являются дубликатами. То что, фильм может иметь несколько номеров удостоверений указано в описании данных, так как удостоверение выдается не только на прокат в кинотеатрах, но отдельно на показ на ТВ, на показ на кабельных каналах, на выпуск фильмов на DVD и т.д. В итоге были удалено более 9% фильмов, в том числе те, которые имели господдержку и фильмы вышедшие в прокат (см.код ниже). А эти данные требуется анализировать в следующих разделах проекта.</font><br>
# <font color='DarkMagenta'>👉 Необходимо отметить, что в первом задании шага 3 необходимо сделать анализ фильмов вышедших в прокат и посчитать долю таких фильмов. От какого общего количества фильмов расчитывать долю не сказано, но по логике надо исключать повторы в названии фильмов. Но в этом случае, что бы не потерять финансовые данные, необходимо отфильтровывать только повторы фильмов, у которых нулевые финансовые показатели. Но делать это следует не в разделе предобработки, а в шаге 3 путем создания отдельной выборки с удаленными повторами в названиях фильмов.<br>В реальных проектах при неопределенности в ТЗ следует обращаться к заказчику за уточнением. В учебном проекте можно просто сделать два вида расчета долей фильмов в прокате, по всему датасету и по выборке без повторов фильмов, но с сохранением финансовых данных.</font>

# %% [markdown]
# Очень согласен.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 3</b></font><br>
# <font color='DarkGreen'>👌 Всегда надо помнить, что удаление данных в какой-то колонке ведет к удалению значимых данных в другой. По этому лучше при анализе просто создавать отфильтрованную выборку, а не удалять строки.</font>

# %%
# Комментарий ревьюера 2
# Проверим сколько удалено строк датасета и финансовых данных
data_set = data.copy()           # создаем копию текущего датасета
a, b  = len(temp), len(data_set)
print(f'Количество строк исходное {a}, Количество строк после обработки {b}, % потерянных строк', round((a-b)/a*100, 2))
fin_list = ['refundable_support', 'nonrefundable_support', 'budget', 'box_office']
for i in fin_list:
    temp1, temp2 = data_set[i].sum(), temp[i].sum()
    print(f'Колонка {i}: сумма исходная {temp1}, сумма после обработки {temp2}, % потерь', round((temp2-temp1)/temp2*100, 2))
# Out:
# Количество строк исходное 7486, Количество строк после обработки 7484, % потерянных строк 0.03
# Колонка refundable_support: сумма исходная 3939000000.0, сумма после обработки 3939000000.0, % потерь 0.0
# Колонка nonrefundable_support: сумма исходная 16261688312.0, сумма после обработки 16261688312.0, % потерь 0.0
# Колонка budget: сумма исходная 42240265939.0, сумма после обработки 42240265939.0, % потерь 0.0
# Колонка box_office: сумма исходная 241519722477.13, сумма после обработки 241519722477.13, % потерь 0.0

# %% [markdown]
# #### Шаг 2.4. Изучите категориальные значения
#
# - Посмотрите, какая общая проблема встречается почти во всех категориальных столбцах;
# - Исправьте проблемные значения в поле `type`.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_1" aria-expanded="false" aria-controls="collapseHint_1">Подсказка</button>
#         </div>
#         <div id="collapseHint_1" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# В поле <code>type</code> есть несколько значений, у которых появился пробел в начале строки. Самый простой способ их «починить» -- использовать метод <a href="https://pandas.pydata.org/docs/reference/api/pandas.Series.str.strip.html#pandas.Series.str.strip">.str.strip</a>. Этот метод удаляет все пробелы, которые встречаются в начале и в конце строки. Применяют его таким образом:<br>
# <code>df['type'].str.strip()</code>
#             </div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# Среди столбцов в таблице есть категориальные, которые важно и не очень сложно проверить на наличие повторов.
#
# **Столбцы:**
# - type,
# - production_country,
# - age_restriction
# - genres

# %% [markdown]
# Посмотрим все уникальные значения для 4 категориальных столбцов.

# %%
# Проверка уникальных значений в столбцах
unique_values = {
    'type': data['type'].unique(),
    'production_country': data['production_country'].unique(),
    'age_restriction': data['age_restriction'].unique(),
    'genres': data['genres'].unique()
}

# Печать уникальных значений
for column, values in unique_values.items():
    print(f"Уникальные значения в столбце {column}:")
    print(values)
    print("\n")
# Out:
# Уникальные значения в столбце type:
# ['Художественный', 'Анимационный', 'Прочие', 'Документальный', 'Научно-популярный', ' Художественный', ' Анимационный', 'Музыкально-развлекательный']
# Categories (8, object): ['Художественный', 'Анимационный', 'Прочие', 'Документальный', 'Научно-популярный', ' Художественный', ' Анимационный', 'Музыкально-развлекательный']
#
#
# Уникальные значения в столбце production_country:
# ['США' 'СССР' 'Франция' 'СССР, Венгрия' 'Германия-Великобритания'
#  'Великобритания - Италия' 'Чехословакия' 'США - Франция - Турция'
#  'Новая Зеландия' 'Канада - Франция - Испания' 'США-Германия'
#  'США - Великобритания' 'Великобритания' 'США - Германия'
#  'Франция - Мексика - США' 'Россия, Казахстан, США' 'СССР, Швеция'
#  'СССР, Франция, Англия, Куба, ГДР' 'Германия'
#  'Великобритания-США-Германия-КНР' 'СССР, ЧССР, Западный Берлин, ПНР'
#  'СССР, Италия' 'Гонконг, КНР' 'США - Франция'
#  'США - Япония - Франция - Великобритания'
# ...

# %% [markdown]
# **1.type:**
# Некоторые значения содержат лишние пробелы (например, " Художественный", " Анимационный").
#
# **2.production_country:**
# В данном столбце используются разные разделители между странами, иногда встречаются "-", ",", " ".
#
# **3.age_restriction:**
# В столбце нет очевидных ошибок.
#
# **4.genres:**
# Некоторые значения содержат несколько жанров, разделённых запятой (например, 'боевик,драма,мелодрама'). Чтобы проанализировать данные по отдельным жанрам, можно разделить эти строки на несколько значений или использовать метод “мульти-меток”.

# %% [markdown]
# Столбец **type**
#
# Заметим, что в списке есть повторы, в которых есть пробелы в начале строки.

# %%
#Посмотрим количество уникальных значений в столбцe, а также их список. 
display(data['type'].unique())

#Удалим возможные пробелы в начале и конце строк
data['type'] = data['type'].str.strip()
display(len(data['type'].unique())) 

#Количество категорий уменьшилось с 8 до 6.
# Out:
# ['Художественный', 'Анимационный', 'Прочие', 'Документальный', 'Научно-популярный', ' Художественный', ' Анимационный', 'Музыкально-развлекательный']
# Categories (8, object): ['Художественный', 'Анимационный', 'Прочие', 'Документальный', 'Научно-популярный', ' Художественный', ' Анимационный', 'Музыкально-развлекательный']
# 6

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, решили проблему в колонке type.</font>

# %% [markdown]
# Столбец **production_country**

# %%
display(len(data['production_country'].unique()))

#Удалим возможные пробелы в начале и конце строк
data['production_country'] = data['production_country'].str.strip()
data['production_country'] = data['production_country'].str.replace(r'[\s,-]+', ',', regex=True)

display(len(data['production_country'].unique())) 



#Проверим текст на наличие букв "ё" и "й", заменим их на "е" и "и" соответственно. 
data['production_country'] = data['production_country'].str.replace("ё", "е")

data['production_country'] = data['production_country'].str.replace("й", "и")



display(len(data['production_country'].unique())) #Проверим количество
# Out:
# 951
# 813
# 813

# %% [markdown]
# Количество уникальных столбцов уменьшилось с 951 до 813.

# %% [markdown]
# Столбец **age_restriction**

# %%
#Посмотрим общее кол-во уникальных значений

display(len(data['age_restriction'].unique())) #Их 5 - немного, можно посмотреть список.

display((data['age_restriction'].unique()))

#Повторы отсутсвуют.
# Out:
# 5
# ['«18+» - запрещено для детей', '«6+» - для детей старше 6 лет', '«12+» - для детей старше 12 лет', '«16+» - для детей старше 16 лет', '«0+» - для любой зрительской аудитории']
# Categories (5, object): ['«18+» - запрещено для детей', '«6+» - для детей старше 6 лет', '«12+» - для детей старше 12 лет', '«16+» - для детей старше 16 лет', '«0+» - для любой зрительской аудитории']

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Не изучены все колонки с категориальными данными. Необходимо найти общую проблему в этих данных, согласно заданию.</font>

# %% [markdown]
# Столбец **genres**

# %%
print(len(data['genres'].unique()))

data['genres'] = data['genres'].str.strip()
data['genres'] = data['genres'].str.replace(r'[\s,-]+', ',', regex=True)

display(data['genres'].unique())
#display(data.head(20))

print(len(data['genres'].unique()))
# Out:
# 743
# array(['боевик,драма,мелодрама', 'драма,военный',
#        'фантастика,боевик,триллер', 'драма', 'мелодрама,комедия',
#        'мюзикл,мелодрама,комедия', 'комедия,криминал',
#        'боевик,триллер,детектив', 'боевик,драма,приключения',
#        'драма,спорт', 'триллер,драма,мелодрама', 'комедия,мелодрама',
#        'драма,мелодрама,комедия', 'драма,мелодрама', 'драма,история',
#        'драма,мелодрама,семейный', 'комедия,мелодрама,криминал',
#        'комедия', 'боевик,драма,криминал', 'драма,комедия',
#        'ужасы,фантастика,комедия', 'мультфильм,короткометражка,мелодрама',
#        'драма,криминал', 'мультфильм,фантастика,фэнтези',
#        'триллер,драма,криминал', 'драма,мелодрама,биография',
#        'драма,комедия,военный', 'фантастика,драма,детектив',
#        'мюзикл,семейный', nan, 'военный,приключения,драма',
#        'документальный,драма', 'драма,биография,история',
#        'боевик,триллер,драма', 'фэнтези,боевик',
# ...

# %% [markdown]
# Можно в жанры унифицировать, оставив только первое слово. Да, в таком случае мы потеряем некоторую информацию о жанрах, но это поможет использовать информацию для анализа жанров. Анализ 743 категорий фильмов не даст плодов.

# %%
data['genres'] = data['genres'].str.split(',').str[0]
print(len(data['genres'].unique()))
# Out:
# 29

# %% [markdown]
# 29 жанров сильно проще анализировать, поэтому оставим так.

# %% [markdown]
# # Вывод по обработке категориальных данных:
#
# 1. Столбец `type`:
# - В данном столбце были обнаружены лишние пробелы в начале некоторых значений.
# - После удаления пробелов количество уникальных значений уменьшилось с 8 до 6, что говорит об успешном исправлении.
#
# 2. Столбец `production_country`:
# - В этом столбце использовались различные разделители между странами (запятая, пробел, дефис).
# - Были удалены лишние пробелы, а также произведена унификация разделителей (замена пробелов и дефисов на запятые).
# - Дополнительно была проведена замена символов "ё" на "е" и "й" на "и".
# - Это привело к уменьшению количества уникальных значений с 951 до 831.
#
# 3. Столбец `age_restriction`:
# - В этом столбце ошибки не были обнаружены, а уникальные значения соответствуют необходимым возрастным ограничениям.
# - Всего 5 уникальных значений, и повторы отсутствуют.
#
# 4. Столбец `genres`:
# - В столбце `genres` были представлены несколько жанров в одной строке, что затрудняло анализ.
# - Для унификации и упрощения анализа было решено оставить только первый жанр в каждой строке, что уменьшило количество уникальных значений с 743 до 29.
# - Это позволяет легче анализировать данные по жанрам, сосредоточившись на наиболее распространённых категориях.
#
# # Общий вывод:
# Проделана значительная работа по очистке и унификации категориальных данных. В результате удалось устранить лишние пробелы, унифицировать разделители и сократить количество уникальных значений в столбцах `type`, `production_country` и `genres`. Эти изменения позволяют упростить анализ данных и избежать излишней сложности при дальнейшей обработке и анализе.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkMagenta'>👉 Общая проблема многих колонок с категориальными данными связана с тем, что они содержат очень много уникальных значений из-за того, что в них идет перечисления отдельных признаков. Так как такие колонки анализировать не возможно, далее выделяем основной жанр и главного режиссёра в отдельные колонки.</font>

# %% [markdown]
# #### Шаг 2.5. Проверьте количественные значения
#
# - Проверьте, обнаружились ли в таких столбцах подозрительные данные. Как с такими данными лучше поступить?
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_budget" aria-expanded="false" aria-controls="collapseHint_budget">Подсказка</button>
#         </div>
#         <div id="collapseHint_budget" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Обратите внимание на описание столбца <code>budget</code>. Как этот столбец соотносится с двумя другими: <code>refundable_support</code> и <code>nonrefundable_support</code>?
#             </div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Рекомендуется для анализа количественных данных посмотреть сводную статистику: `df.describe()`.</font>

# %% [markdown]
# На данном этапе следует тщательно проверить столбцы "budget", "refundable_support", "nonrefundable_support".
# Следует учесть, что:
#
# - Бюджет не может быть меньше, чем refundable_support, nonrefundable_support, так как бюджет уже включает эту поддержку.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Эти комментарии должны быть в ячейках Markdown, а не в ячейке кода. Это относится ко всему проекту. Проект должен иметь структуру отделяющую код от комментариев, что делаем и результатов преобразования. В ячейке кода размещаются только комментарии относящиеся непосредственно к коду: описание переменных, подаваемые параметры в функцию, описание возвращаемого значения из функции и т.п.</font>
# ![image.png](attachment:image.png)

# %% [markdown]
# Подправил

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 3</b></font><br>
# <font color='DarkMagenta'>👉 Здесь да, а в других ячейках нет. 😢</font>

# %%
display(len(data[(data['nonrefundable_support'] + data['refundable_support']) > data['budget']]))

display(data[(data['nonrefundable_support'] + data['refundable_support']) > data['budget']])
# Out:
# 17
#                        title   puNumber show_start_date            type  \
# 2053                     14+  111023614      2014-12-19  Художественный
# 2058               Дуxless 2  111000415      2015-01-26  Художественный
# 2472             Воин (2015)  111017315      2015-09-28  Художественный
# 2532                 Бармен.  111009615      2015-05-26  Художественный
# 2615     Савва. Сердце воина  114001715      2015-07-21    Анимационный
# 2684          Тряпичный союз  111010215      2015-06-08  Художественный
# 2788      Срочно выйду замуж  111017115      2015-09-30  Художественный
# 2874       Помню - не помню!  111004916      2016-03-01  Художественный
# 3047  Любовь с ограничениями  111008216      2016-04-29  Художественный
# 3565       Притяжение (2016)  111018116      2016-12-16  Художественный
# 3675                Чудо-юдо  114001817      2017-06-27    Анимационный
# 3739                    Мифы  111004317      2017-06-07  Художественный
# ...

# %% [markdown]
# Есть 17 строк, у которых ошибочно заполнены строки в столбце 'budget'. Значения в строке бюджет равны 0.
#
#
# Так как нам далее будет важно проанализировать процент гос поддержки в общем бюджете фильма, предлагаю удалить 17 значений.
# Заполнить столбец Бюджет суммой "nonrefundable_support" и "refundable_support" было неверным, так как обычно бюджет больше чем только поддержка.

# %%
data = data[(data['budget'].isna()) | ((data['nonrefundable_support'] + data['refundable_support'])<= data['budget'])]

# %% [markdown]
# Оставляем только те строки, где не выполняется условие **budget > refundable_support + nonrefundable_support**

# %%
#Посмотрим, сколько осталось пропусков.
display(data.info())

#Теперь три столбца budget, refundable_support, nonrefundable_support содержит одинаковое количество данных.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7467 entries, 0 to 7483
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7467 non-null   object
#  1   puNumber               7467 non-null   object
#  2   show_start_date        7467 non-null   datetime64[ns]
#  3   type                   7467 non-null   object
#  4   film_studio            7449 non-null   object
#  5   production_country     7465 non-null   object
#  6   director               7458 non-null   object
#  7   producer               7293 non-null   object
#  8   age_restriction        7467 non-null   category
#  9   refundable_support     315 non-null    float64
#  10  nonrefundable_support  315 non-null    float64
#  11  budget                 315 non-null    float64
#  12  financing_source       7467 non-null   category
#  13  ratings                6501 non-null   float64
# ...

# %% [markdown]
# Столбец **box_office**

# %%
print(data.columns)
# Out:
# Index(['title', 'puNumber', 'show_start_date', 'type', 'film_studio',
#        'production_country', 'director', 'producer', 'age_restriction',
#        'refundable_support', 'nonrefundable_support', 'budget',
#        'financing_source', 'ratings', 'genres', 'box_office'],
#       dtype='object')

# %%
#Добавим столбец года
data['year'] = data['show_start_date'].dt.year

pivot_years_median = data.pivot_table(index = 'year', values = 'box_office', aggfunc = ['median', 'sum', 'count'])
display(pivot_years_median)

#Заметим, что за 2010 - 2014 года данные сильно отличаются от последующих годов. 


#Заметим, что сборы меньше 100 000 рублей достаточно много. Кажется, что это ошибка. 

#Допускаю, что это ошибка. Думаю, что будет верным домножить такие значения на 1000. 
data.loc[data['box_office'] < 100000, 'box_office'] = data.loc[data['box_office'] < 100000, 'box_office'] * 1000

print(len(data[data['box_office'] == 0]))

#Медиана за 2010 - 2014 очень низкая относительно других годов.
#Это связано с тем, что значения низкие, а не с наличием нулевых значений.

#
#data.loc[data['year'].isin([2010, 2011, 2012, 2013]), 'box_office'] =  data.loc[data['year'].isin([2010, 2011, 2012, 2013]), 'box_office'] / 1000
pivot_years_median = data.pivot_table(index = 'year', values = 'box_office', aggfunc = ['median', 'sum', 'count'])

#Также значения, сборы которых равны нулю

data = data.drop(data[data['box_office'] == 0].index)
# Out:
#          median            sum      count
#      box_office     box_office box_office
# year
# 2010    1700.00     2428654.00        105
# 2011    3000.00    14102765.00        109
# 2012    5660.00     6955423.00        128
# 2013    3522.50    29799706.20        184
# 2014   18137.50  7434717843.10        278
# 2015 4784781.50 38527827199.09        459
# 2016 3776087.56 46742316269.48        523
# 2017 9919415.00 48458147253.75        355
# 2018 8751895.75 49251991405.20        471
# 2019 4601033.60 48278101953.08        529
# 24

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Какое основание для искажения данных сборов в прокате? Почему умножаем на 1000, а не 10000? Или на 100? Высказано предположение, но оно не подтверждено информацией из других источников.</font>

# %%
# Комментарий ревьюера
temp1, temp2 = data.box_office.sum(), temp.box_office.sum()
temp1, temp2, round((temp1-temp2)/temp1*100, 2)
# Out:
# (250606353934.59998, 241519722477.13, 3.63)

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Не проверены возможные аномалии во всех колонках с количественными данными. Не проанализированы их причины.<br>Только не надо их сразу удалять.</font>

# %% [markdown]
# Построим "ящик с усами" для каждого столбца, чтобы проверить аномалии.

# %%
# Список столбцов для анализа
columns_to_plot = ['nonrefundable_support', 'refundable_support', 'budget', 'box_office']

# Построение графиков и описание данных
for column in columns_to_plot:
    column_data = data[column].dropna()  # Удаляем NaN значения
    column_data = column_data[column_data != 0]  # Удаляем нулевые значения для refundable_support
    
    if not column_data.empty:  # Проверяем, есть ли данные для построения
        print(f"Описание данных для {column}:")
        print(column_data.describe())
        
        # Вычисляем границы для выбросов
        Q1 = column_data.quantile(0.25)
        Q3 = column_data.quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Находим выбросы
        outliers = column_data[(column_data < lower_bound) | (column_data > upper_bound)]
        print(f"Количество выбросов для {column}: {len(outliers)}")
        print("\n")
        
        # Построение графика
        plt.figure(figsize=(12, 8)) 
        plt.boxplot(column_data)  
        plt.title(f'Boxplot для {column}') 
        plt.xlabel('Параметр')  
        plt.ylabel('Значение')  
        plt.xticks([1], [column])  # название столбца как метку оси X
        plt.show()
# Out:
# Описание данных для nonrefundable_support:
# count         307.00
# mean     49360647.71
# std      60150060.16
# min       3000000.00
# 25%      25000000.00
# 50%      30000000.00
# 75%      40000000.00
# max     400000000.00
# Name: nonrefundable_support, dtype: float64
# Количество выбросов для nonrefundable_support: 42
# Описание данных для refundable_support:
# count         101.00
# mean     36188118.81
# std      32981331.01
# min       3500000.00
# 25%      15000000.00
# 50%      25000000.00
# 75%      50000000.00
# max     180000000.00
# Name: refundable_support, dtype: float64
# Количество выбросов для refundable_support: 5
# Описание данных для budget:
# count          315.00
# mean     134096082.35
# std      191226039.63
# min       14462464.00
# 25%       46153866.50
# 50%       73379554.00
# 75%      150004286.50
# max     2305074303.00
# Name: budget, dtype: float64
# Количество выбросов для budget: 28
# Описание данных для box_office:
# count         3117.00
# ...

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, исправили.</font>

# %% [markdown]
# # Вывод по обработке количественных данных:
#
# 1. **nonrefundable_support**:
#     - Среднее: 48.37 млн, Стандартное отклонение: 56.95 млн, что очень много.
#     - Больше всего данных сосредоточено вокруг значений до 40 млн.
#     - Максимум: 400 млн (выброс).
#     - Количество выбросов: 41. Выбросов немного, но они оказывают существенное влияение на выборку.
#     - **Вывод**: Большая часть поддержки — невозвратная, что объясняет высокие значения и выбросы. Эти средства могут быть выделены для крупных и долгосрочных проектов.
#
# 2. **refundable_support**:
#     - Среднее: 35.86 млн, Стандартное отклонение: 32.53 млн.
#     - Больше всего проектов имеют нулевую поддержку.
#     - Максимум: 180 млн.
#     - Количество выбросов: 5.
#     - **Вывод**: Возвратная поддержка используется реже и в исключительных случаях, что объясняет нулевые значения и редкие высокие суммы.
#
# 3. **budget**:
#     - Среднее: 131.97 млн, Стандартное отклонение: 186.47 млн.
#     - Бюджеты сильно варьируются, от 14.5 млн до 2.3 млрд.
#     - Количество выбросов: 27.
#     - Вывод: Высокая вариативность бюджетов обусловлена различием в масштабах проектов. Большие бюджеты часто требуют невозвратной поддержки.
#
# 4. **box_office**:
#     - Среднее: 79.58 млн, Стандартное отклонение: 237.6 млн.
#     - Максимум: 3 млрд.
#     - Количество выбросов: 434.
#     - **Вывод**: Разница между успешными и неудачными проектами. Некоторые фильмы с огромными кассовыми сборами значительно увеличивают среднее.
#
# **Общие выводы**:
# - Важно, что большая часть поддержки — невозвратная, что объясняет высокие значения и выбросы в данных.
# - Бюджеты и кассовые сборы варьируются в зависимости от масштаба проектов, поддерживаемых государством, и их успешности на рынке.

# %%
# Комментарий ревьюера
# Проверим сколько удалено строк датасета
a, b = len(temp), len(data)
print(a, b, round((a-b)/a*100, 2))
# Out:
# 7486 7443 0.57

# %% [markdown]
# #### Шаг 2.6. Добавьте новые столбцы

# %% [markdown]
# - Создайте столбец с информацией о годе проката. Выделите год из даты премьеры фильма.

# %%
#Добавил на предыдущем шаге
#data['year'] = data['show_start_date'].dt.year

data.head(20)
# Out:
#                                                 title   puNumber  \
# 0                                    Открытый простор  221048915
# 1                                Особо важное задание  111013716
# 2                                        Особо опасен  221038416
# 3                                        Особо опасен  221026916
# 4                                        Особо опасен  221030815
# 5                                   Остановился поезд  111013816
# 6                                     Любовь и голуби  111007013
# 7                                   Любовь и сигареты  221074614
# 8                                  Отпетые мошенники.  121011416
# 9                                 Отпуск за свой счет  111019114
# 10  Превосходство Борна /По одноименной новелле Ро...  221031416
# 11                                       Ответный ход  111019014
# 12  Малышка на миллион /По мотивам рассказов Ф.Х.Т...  221011415
# ...

# %% [markdown]
# - Создайте два столбца: с именем и фамилией главного режиссёра и основным жанром фильма. В столбцы войдут первые значения из списка режиссёров и жанров соответственно.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_2" aria-expanded="false" aria-controls="collapseHint_2">Подсказка</button>
#         </div>
#         <div id="collapseHint_2" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Чтобы создать такие столбцы, лучше всего использовать собственную функцию. Эту функцию можно применить к двум столбцам сразу.
#             </div>
#         </div>
#     </div>
# </div>

# %%
#Создадим столбцы
data['first_director'] = ''
data['main_genre'] = ''
    
#Создаем функцию, которая будет разбивать на список по запятым. После чего - оставлять только первый элемент.
def dir(x):
    if isinstance(x, str):
        return x.split(',')[0]

#Применяем к двум функциям сразу
data['first_director'] = data['director'].apply(dir)
data['main_genre'] = data['genres'].apply(dir)

# %%
#Посмотрим, что получилось
data.head()
# Out:
#                   title   puNumber show_start_date            type  \
# 0      Открытый простор  221048915      2015-11-27  Художественный
# 1  Особо важное задание  111013716      2016-09-13  Художественный
# 2          Особо опасен  221038416      2016-10-10  Художественный
# 3          Особо опасен  221026916      2016-06-10  Художественный
# 4          Особо опасен  221030815      2015-07-29  Художественный
#
#                                          film_studio production_country  \
# 0  Тачстоун Пикчерз, Кобальт Пикчерз, Бикон Пикче...                США
# 1                              Киностудия "Мосфильм"               СССР
# 2  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 3  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 4  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
#
#             director                                           producer  \
# ...

# %% [markdown]
# - Посчитайте, какую долю от общего бюджета фильма составляет государственная поддержка.

# %% [markdown]
# **Доля от общего бюджета фильма в процентах.**

# %%
data['dolya_%'] = (data['refundable_support'] + data['nonrefundable_support'] ) / data['budget'] * 100

display(data.tail(30))
# Out:
#                                              title   puNumber show_start_date  \
# 7454                                         Холоп  111021719      2019-12-19
# 7455                         Шарнохой - жёлтый пёс  111021819      2019-12-12
# 7456                                        Курьер  121037019      2019-12-12
# 7457                       Эрмитаж. Сила искусства  126007819      2019-12-11
# 7458                              Школа номер один  113001619      2019-12-16
# 7459                                   Тайна Мосли  124010419      2019-12-12
# 7460                    МУЛЬТ в кино. Выпуск № 109  114004919      2019-12-21
# 7461                        Небо измеряется милями  111021919      2019-12-19
# 7462                                 Союз спасения  111022019      2019-12-26
# 7463                      Fair play (Честная игра)  211055919      2019-12-17
# 7464                   Иван Царевич и Серый Волк 4  114005019      2019-12-20
# ...

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Правильно сделано задание по созданию колонок.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Здесь ожидаются обобщающие выводы по разделу предобработки данных.</font>

# %% [markdown]
# # Общий вывод по разделу обработки данных:
#
# В ходе обработки данных было выполнено несколько шагов, направленных на улучшение качества и унификацию как категориальных, так и количественных столбцов. В категориальных данных было устранено несколько проблем: лишние пробелы в значениях столбца type были удалены, что привело к уменьшению уникальных значений, а в столбце production_country произведена унификация разделителей, что также помогло сократить количество уникальных значений. В столбце genres была оставлена только первая категория жанра для каждого фильма, что значительно упростило анализ и позволило сосредоточиться на наиболее распространённых жанрах. В age_restriction ошибок не было, и столбец оказался полностью корректным. Эти изменения позволили сократить количество уникальных значений в категориальных данных и повысить консистентность данных, что делает их более удобными для анализа.
#
# В количественных данных были обнаружены выбросы, которые не оказали значительного влияния на общий анализ, но важно их учитывать. Столбцы nonrefundable_support, refundable_support, budget и box_office показали большую вариативность, при этом выбросы в данных были отфильтрованы и учтены. Например, невозвратная поддержка имеет высокие значения и выбросы, что связано с крупными и долгосрочными проектами, а возвратная поддержка встречается реже, с максимальными значениями, объясняющимися исключительными случаями. Бюджеты варьируются от меньших до очень крупных сумм, что обусловлено различиями в масштабах проектов, а кассовые сборы демонстрируют значительную разницу между успешными и неудачными проектами.
#
# Дополнительно были добавлены промежуточные столбцы для удобства последующего анализа.
#
# В результате всех выполненных операций данные стали более чистыми и унифицированными, что способствует более точному и эффективному анализу, позволяя сделать выводы о поддержке проектов, их бюджете и успешности на рынке.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, теперь правильно.</font>

# %% [markdown]
# ### Шаг 3. Проведите исследовательский анализ данных

# %% [markdown]
# - Посмотрите, сколько фильмов выходило в прокат каждый год. Обратите внимание, что данные о прокате в кинотеатрах известны не для всех фильмов. Посчитайте, какую долю составляют фильмы с указанной информацией о прокате в кинотеатрах. Проанализируйте, как эта доля менялась по годам. Сделайте вывод о том, какой период полнее всего представлен в данных.

# %%
# Отфильтруем фильмы, у которых есть информация о прокате
data_box_office = data.dropna(subset=['box_office'])

# Посмотрим, сколько фильмов вышло в прокат каждый год
display(data_box_office['year'].value_counts().sort_index())

pivot = data_box_office.pivot_table(columns='year', aggfunc='size')

# Построим график
pivot.plot(title='Количество фильмов в прокате по годам', figsize=(14, 6))
plt.xlabel('Год')
plt.ylabel('Количество')
plt.show()

# Доля фильмов с указанной информацией о прокате в кинотеатрах
total_films = data.shape[0]
films_with_box_office = data_box_office.shape[0]
print('Доля фильмов с информацией о прокате:', round(films_with_box_office / total_films * 100, 3), '%')
# Out:
# 2010    101
# 2011    109
# 2012    123
# 2013    179
# 2014    272
# 2015    456
# 2016    522
# 2017    355
# 2018    471
# 2019    529
# Name: year, dtype: int64
# Доля фильмов с информацией о прокате: 41.878 %

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkMagenta'>👉 Подписи осей и название нужны для того, чтобы сделать диаграммы и графики понятными и информативными, особенно для заказчика проекта. Без них было бы сложно определить, что именно изображено на графике и какие значения соответствуют каждой оси, так как заказчик не обязан разбираться в коде. Более того, подписи осей помогают установить контекст и понять, какие переменные представлены на графике. По этому при дальнейшем комментировании результатов анализа и визуализации, становятся понятны сделанные из анализа выводы. </font>

# %% [markdown]
# Из анализа видно, что количество фильмов, вышедших в прокат, значительно увеличилось с 2010 по 2019 годы. Особенно заметен рост в 2015 году, когда количество фильмов перешло отметку 450, а в 2019 году достигло более 500 фильмов. Это может свидетельствовать о росте производства фильмов и увеличении их выхода в прокат с течением времени либо с отсутствием данных за предыдущие года (пред 2015).
#
# Доля фильмов с информацией о прокате в кинотеатрах составляет 41.878%. Это означает, что менее половины фильмов в данных имеют информацию о сборах в прокате, что может свидетельствовать о недостаточной полноте данных по этой категории для большинства фильмов.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Визуализация данных графиками и диаграммами подразумевает подписи всех осей и название графика  на русском языке, при необходимости наличие меток. Это относится ко всем графикам/диаграммам проекта и является критической ошибкой. Правила оформления проектов описаны "Полезных инструкциях для учёбы".</font><br>
# <font color='Red'>🛠 Что является фактом выхода в прокат фильма? Наличие сборов в прокате. Не все фильмы с установленной датой премьеры попадают в прокат, а здесь это не учтено. В итоге сделан анализ всех фильмов, а не вышедших в прокат, что требуется в задании.</font>

# %%
pivot_years = data.pivot_table(index = 'year', values = 'box_office', aggfunc = lambda x: (x.count()/x.size) * 100)

display(pivot_years)

pivot_years.plot(figsize = (14, 6))
plt.title('Доля фильмов с данными о сборах по годам')
plt.xlabel('Год')
plt.ylabel('Доля, %')
plt.show()
# Out:
#       box_office
# year
# 2010       10.32
# 2011       17.52
# 2012       20.92
# 2013       28.64
# 2014       34.00
# 2015       65.52
# 2016       64.13
# 2017       70.58
# 2018       53.10
# 2019       56.94

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 3</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, теперь правильно.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='Red'>🛠 График не оформлен, нет названия.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 График не оформлен необходимым образом.</font>

# %% [markdown]
# Наиболее полная информация информация о годах представлена с 2015 года до 2018.

# %% [markdown]
# - Изучите, как менялась динамика проката по годам. В каком году сумма сборов была минимальной? А максимальной?

# %%
pivot_years_median = data.pivot_table(index = 'year', values = 'box_office', aggfunc = ['median', 'sum', 'count'])

display(pivot_years_median)

print(len(data[data['box_office'] < 1000000]))
# Out:
#           median            sum      count
#       box_office     box_office box_office
# year
# 2010  1657000.00   570073441.00        101
# 2011  2850000.00  1109236535.00        109
# 2012  3240000.00  1514779090.00        123
# 2013  2455000.00  1571920042.20        179
# 2014  1806036.00  8876483134.60        272
# 2015  9432442.15 40145567739.19        456
# 2016  8221161.44 49004504816.48        522
# 2017 10741189.00 48853073931.75        355
# 2018 10390929.84 49845888413.70        471
# 2019  5056881.33 49114826790.68        529
# 659

# %%
display(data[(data['year'] == 2019) & (data['box_office'] < 100000)].head(30))
# Out:
# Empty DataFrame
# Columns: [title, puNumber, show_start_date, type, film_studio, production_country, director, producer, age_restriction, refundable_support, nonrefundable_support, budget, financing_source, ratings, genres, box_office, year, first_director, main_genre, dolya_%]
# Index: []

# %%
#Изменение динамики "box_office" по годам

pivot_years_sum = data.pivot_table(index = 'year', values = 'box_office', aggfunc = 'sum')
#pivot_years_sum = pivot_years_sum['box_office'].where('b')
display(pivot_years_sum)


# Визуализируем динамику суммы сборов по годам
pivot_years_sum.plot(kind='bar', figsize=(14, 6))
plt.title('Сумма сборов по годам')
plt.xlabel('Годы')
plt.ylabel('Сумма сборов')
plt.show()
# Out:
#          box_office
# year
# 2010   570073441.00
# 2011  1109236535.00
# 2012  1514779090.00
# 2013  1571920042.20
# 2014  8876483134.60
# 2015 40145567739.19
# 2016 49004504816.48
# 2017 48853073931.75
# 2018 49845888413.70
# 2019 49114826790.68

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Первый график не оформлен необходимым образом.</font>

# %% [markdown]
# **Удалил первый. 2 графика были одинаковыми.**

# %% [markdown]
# - С помощью сводной таблицы посчитайте среднюю и медианную сумму сборов для каждого года.

# %%
# Медиана и сумма по годам
pivot_years_median = data.pivot_table(index='year', values='box_office', aggfunc=['median', 'sum', 'count'])

# В случае фильмов с маленькими сборами, которые могут быть значениями меньше 100 000, можно нормализовать
data.loc[data['box_office'] < 100000, 'box_office'] = data.loc[data['box_office'] < 100000, 'box_office'] * 1000

pivot_years_median = data.pivot_table(index='year', values='box_office', aggfunc=['median', 'sum', 'count'])

display(pivot_years_median)
# Out:
#           median            sum      count
#       box_office     box_office box_office
# year
# 2010  1700000.00   644998441.00        101
# 2011  2850000.00  1109236535.00        109
# 2012  3475000.00  1594699090.00        123
# 2013  2700000.00  1611880042.20        179
# 2014  1817264.50  8926433134.60        272
# 2015  9432442.15 40145567739.19        456
# 2016  8221161.44 49004504816.48        522
# 2017 10741189.00 48853073931.75        355
# 2018 10390929.84 49845888413.70        471
# 2019  5056881.33 49114826790.68        529

# %% [markdown]
# Несмотря на общий рост, медианные сборы фильмов остаются стабильными или растут медленнее, что указывает на увеличение числа фильмов с низкими или средними сборами. Это отражает высокую конкуренцию на рынке кино.
#
# Таким образом, 2015 и 2016 годы являются рекордными по общим сборам, но рост числа фильмов с меньшими сборами может объяснять снижение медианных значений в последние годы.
#
# Медианное значение часто ниже среднего, потому что существует большое количество фильмов с низкими сборами, также есть некоторые картины с аномально большими сборами.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Нет анализа и вывода по отличию средней и медианой суммы сбора.</font>

# %%
pivot_years_sum = data.pivot_table(index='year', values='box_office', aggfunc='sum')

# Визуализируем динамику суммы сборов по годам
pivot_years_sum.plot(kind='bar', figsize=(14, 6))
plt.title('Сумма сборов по годам')
plt.xlabel('Годы')
plt.ylabel('Сумма сборов')
plt.show()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошая визуализация и правильно, что оси подписаны и есть название графика.</font>

# %% [markdown]
# - Определите, влияет ли возрастное ограничение аудитории («6+», «12+», «16+», «18+» и т. д.) на сборы фильма в прокате в период с 2015 по 2019 год? Фильмы с каким возрастным ограничением собрали больше всего денег в прокате? Меняется ли картина в зависимости от года? Если да, предположите, с чем это может быть связано.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Можно сократить строку колонки возрастной категории до значения возраста в кавычках, для этого следует извлечь из строки символы до разделителя `-`.</font>

# %%
# Фильтруем данные
data15_19 = data[(data['show_start_date'].dt.year >= 2015) & (data['show_start_date'].dt.year <= 2019)]


age_box_office = data15_19.groupby('age_restriction')['box_office'].sum().sort_values(ascending=False)
display(age_box_office)

# Визуализация
age_box_office.plot(kind='bar', title='Сумма сборов по возрастным ограничениям', figsize=(10, 6))
plt.xlabel('Возрастное ограничение')
plt.ylabel('Сумма сборов')
plt.show()
# Out:
# age_restriction
# «16+» - для детей старше 16 лет          77044101694.10
# «12+» - для детей старше 12 лет          61038629059.10
# «6+» - для детей старше 6 лет            55684999706.02
# «18+» - запрещено для детей              41882644720.61
# «0+» - для любой зрительской аудитории    1313486511.97
# Name: box_office, dtype: float64

# %% [markdown]
# Заметим, что больше всего собрали фильмы, у которых ограниечение 16+. Меньше всего те, у кого нет ограничения. Речь идет о мультфильмах / фильмах для детей.

# %%
yearly_age_box_office = data15_19.groupby([data15_19['show_start_date'].dt.year, 'age_restriction'])['box_office'].sum().unstack()

# Визуализация
yearly_age_box_office.plot(kind='bar', stacked=True, figsize=(14, 7), title='Сумма сборов по возрастным ограничениям по годам')
plt.xlabel('Год')
plt.ylabel('Сумма сборов')
plt.legend(title='Возрастное ограничение', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# Заметим, что структура доходов в зависимости от возрастного ограничения не сильно изменялась. То есть пропорции оставались примерно те же. Больше всего подвержены изменения в % отношении сборов - категория 12+, в 2015 году она была самой значимой.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Можно дополнить анализ диаграммой размаха сборов в прокате по возрастным категориям.</font>

# %%
# Комментарий ревьюера 2
import seaborn as sns
temp = data[data.box_office > 0].copy()
# для удобства укоротим названия категорий
def get_first_value(s, sep = ','):  # Функция для выбора первого элемента из перечисления
    value_lst = s.split(sep=sep)
    return value_lst[0]

temp['age_restriction'] = temp['age_restriction'].apply(lambda x: get_first_value(x, sep='-'))
# сохраним маску для среза по годам
year_mask = temp['year'] >= 2015

plt.figure(figsize=(8, 8))
(sns.boxplot(data = temp.loc[year_mask], y = 'box_office', x='age_restriction', showfliers=False, showmeans=True)
    .set(title = 'Кассовые сборы в зависимости от возрастной категории', 
         xlabel = 'Возрастные категории', ylabel = 'Кассовый сбор'))
plt.text(0, 3.1e8,'Треугольник показывает среднее значение')
plt.show()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkMagenta'>👉 Для интерпретации диаграмм размаха помогает вспомнить, что означают боксплоты. В данном случае расположение боксплота и медианы показывают у какой возрастной категории стабильно высокие сборы.</font>
# ![image.png](attachment:image.png)

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Не сделаны промежуточные выводы по данному разделу проекта.</font><br>
# <font color='DarkMagenta'>👉 Промежуточный вывод после каждого раздела в проекте помогает понять, какие результаты были получены на данном этапе работы и как они соотносятся с целями и задачами раздела. Он может служить отправной точкой для дальнейшего анализа и развития проекта.<br>
# Кроме того, промежуточный вывод может помочь убедиться, что все необходимые задания были выполнены и результаты соответствуют целям проекта. Это может предотвратить ошибки и проблемы в дальнейшем процессе работы над проектом.<br>
# В целом, написание промежуточного вывода после каждого раздела может быть полезным для понимания прогресса в проекте и обеспечения его качества.<br>
# Промежуточный вывод должен содержать следующие основные моменты:<br>
# - Краткое описание целей и задач раздела.<br>
# - Основные результаты, полученные на данном этапе работы.<br>
# - Анализ полученных результатов и их соответствие целям раздела.<br>
# - Возможные проблемы и трудности, с которыми столкнулись при выполнении раздела.<br>
# - Рекомендации по дальнейшим шагам и развитию проекта.<br>
# Промежуточный вывод должен быть кратким и лаконичным, чтобы не перегружать заказчика лишней информацией.</font>

# %% [markdown]
# ## Промежуточный вывод для раздела "Исследовательский анализ данных"
#
# ### Цели и задачи раздела:
# Целью данного раздела было провести исследовательский анализ данных о фильмах с 2010 по 2019 годы, с фокусом на количество фильмов, динамику сборов, возрастные ограничения и их влияние на сборы.
#
#
# В ходе анализа данных о фильмах с 2010 по 2019 годы мы наблюдаем следующие основные результаты:
#
# 1. **Количество фильмов, вышедших в прокат по годам**:
#     - Количество фильмов, имеющих информацию о сборах в прокате, значительно увеличивалось начиная с 2015 года. Особенно заметен резкий рост в 2015 году, когда количество фильмов превысило 450, а в 2016 и 2019 годах достигало более 500.
#     - Однако доля фильмов с указанной информацией о сборах остается ниже 50%, что указывает на недостаточную полноту данных по этой категории для большинства фильмов.
#
# 2. **Динамика сборов по годам**:
#     - Сумма сборов по годам показала стабильный рост, особенно в 2015-2016 годах, когда общая сумма сборов превысила 40 миллиардов рублей в год. Это отражает рост индустрии, но также и увеличение числа фильмов с низкими или средними сборами, что снижает медианные значения.
#     - Медианные значения сборов остаются стабильными или растут медленнее, что может свидетельствовать о высокой конкуренции на рынке кино, с увеличением числа фильмов с меньшими сборами, и также влияние аномально успешных картин.
#
# 3. **Возрастные ограничения и их влияние на сборы**:
#     - Фильмы с возрастным ограничением «16+» собрали наибольшую сумму сборов, в то время как фильмы с категорией «0+» (для всей аудитории) значительно отставали, что в первую очередь связано с мультфильмами и фильмами для детей.
#     - В динамике сборов по возрастным ограничениям в период с 2015 по 2019 годы структура не претерпела значительных изменений, при этом категория «12+» стала более заметной в 2015 году, но со временем её доля снизилась.
#
#
# Результаты подтверждают гипотезу о расширении киноиндустрии в 2015-2019 годах, с увеличением количества фильмов и общей суммы сборов, несмотря на наличие фильмов с низкими сборами. Медианные значения сборов также показывают высокую конкуренцию на рынке.
#
# Таким образом, данные о кинофильмах с 2015 года предоставляют наиболее полную картину, и можно сделать вывод, что индустрия кино значительно расширялась в эти годы, несмотря на наличие фильмов с менее значительными сборами.

# %% [markdown]
# ### Шаг 4. Исследуйте фильмы, которые получили государственную поддержку
#
# На этом этапе нет конкретных инструкций и заданий — поищите интересные закономерности в данных. Посмотрите, сколько выделяют средств на поддержку кино. Проверьте, хорошо ли окупаются такие фильмы, какой у них рейтинг.

# %% [markdown]
# Определим общую сумму государственной поддержки.
#
# Посмотрим на:
# 	•Суммарный объём возвратной и невозвратной поддержки.
# 	•Средний бюджет фильмов с государственной поддержкой.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Для этого задания следовало создать датасет с отфильтрованными фильмами с господдержкой.</font>

# %%
# Суммарный объём возвратной и невозвратной поддержки
total_refundable_support = data['refundable_support'].sum()
total_nonrefundable_support = data['nonrefundable_support'].sum()
total_support = total_refundable_support + total_nonrefundable_support

print(f"Суммарный объём возвратной поддержки: {total_refundable_support}")
print(f"Суммарный объём невозвратной поддержки: {total_nonrefundable_support}")
print(f"Общий объём государственной поддержки: {total_support}")

# Средний бюджет фильмов с государственной поддержкой
average_budget = data['budget'].mean()
print(f"Средний бюджет фильмов с государственной поддержкой: {average_budget}")
# Out:
# Суммарный объём возвратной поддержки: 3655000000.0
# Суммарный объём невозвратной поддержки: 15153718847.0
# Общий объём государственной поддержки: 18808718847.0
# Средний бюджет фильмов с государственной поддержкой: 134096082.34603174

# %% [markdown]
# Оценим окупаемость фильмов.
#
# Сравним:
#     •Сборы фильма с бюджетом.
#     •Рассчитаем коэффициент окупаемости (сборы/бюджет).
#     •Посмотрим на процент окупаемых фильмов (коэффициент > 1).

# %%
# Убедимся, что сборы и бюджет имеют числовой формат
data['box_office'] = pd.to_numeric(data['box_office'], errors='coerce')
data['budget'] = pd.to_numeric(data['budget'], errors='coerce')

# Удалим строки с отсутствующими значениями в данных о сборах и бюджете
movies_with_data = data.dropna(subset=['box_office', 'budget']).copy()

# Рассчитаем коэффициент окупаемости
movies_with_data['profitability_ratio'] = movies_with_data['box_office'] / movies_with_data['budget']

# Сравнение сборов и бюджета (средние значения)
average_box_office = movies_with_data['box_office'].mean()
average_budget = movies_with_data['budget'].mean()
average_profitability_ratio = movies_with_data['profitability_ratio'].mean()

# Процент фильмов с коэффициентом окупаемости > 1
profitable_movies = movies_with_data[movies_with_data['profitability_ratio'] > 1]
percentage_profitable = len(profitable_movies) / len(movies_with_data) * 100

# Вывод результатов
print(f"Средние сборы фильма: {average_box_office:.2f} руб.")
print(f"Средний бюджет фильма: {average_budget:.2f} руб.")
print(f"Средний коэффициент окупаемости: {average_profitability_ratio:.2f}")
print(f"Процент окупаемых фильмов: {percentage_profitable:.2f}%")

# Отобразим первые несколько строк для визуального анализа
display(movies_with_data[['title', 'box_office', 'budget', 'profitability_ratio']].sort_values(by='profitability_ratio', ascending=False).head(10))
display(movies_with_data[['title', 'box_office', 'budget', 'profitability_ratio']].head())
# Out:
# Средние сборы фильма: 134241923.12 руб.
# Средний бюджет фильма: 134837767.97 руб.
# Средний коэффициент окупаемости: 0.84
# Процент окупаемых фильмов: 25.58%
#                    title    box_office       budget  profitability_ratio
# 7454               Холоп 3073568690.79 160000000.00                19.21
# 5706                 Лёд 1445731797.89 148585222.00                 9.73
# 5747             Я худею  633462266.74  87649127.00                 7.23
# 3229       Гуляй, Вася !  259099078.00  39000000.00                 6.64
# 2701   Самый Лучший День  683029061.40 130619336.00                 5.23
# 2205    8 новых свиданий  393344626.30  77401751.00                 5.08
# 5639          Ёлки Новые  855451052.00 174381922.00                 4.91
# 6176         Непрощенный  393279629.43  82496889.00                 4.77
# 5651      Движение вверх 2779686144.00 590192191.00                 4.71
# 5503  Последний богатырь 1655037688.00 352477575.00                 4.70
# ...

# %% [markdown]
# **Промежуточный вывод.**
#
# 	- Государственная поддержка:
# •Возвратная: 3,655 млн руб., невозвратная: 15,153 млн руб., общая: 18,808 млн руб.
#
# •Основная доля приходится на невозвратную поддержку, что указывает на большие инвестиции в кино.
#
# 	- Средний бюджет фильмов: 134 млн руб. Фильмы с поддержкой имеют крупные бюджеты, рассчитанные на масштабные проекты.
#
# 	- Окупаемость:
# •Средние сборы: 134 млн руб., средний коэффициент окупаемости: 0.84.
#
# •Процент окупаемых фильмов: 25.75%. Большинство фильмов остаются убыточными.
#
# **Успешные проекты:** "Холоп" (19.21), "Лёд" (9.73) и другие показывают, что даже крупнобюджетные проекты могут быть крайне прибыльными при успешном маркетинге и высокой популярности.
#
# **Неуспешные проекты:** Фильмы с коэффициентом окупаемости около 0 (например, "Пока еще жива") страдают от низкой зрительской заинтересованности или недостаточного продвижения.

# %% [markdown]
# Исследуем рейтинги фильмов.
#
# Посмотрим:
# 	•	Средний рейтинг фильмов с поддержкой.
# 	•	Зависимость рейтинга от суммы поддержки.
# 	•	Сравнение с фильмами без государственной поддержки.

# %%
# Средний рейтинг фильмов с государственной поддержкой
movies_with_support = data[data['refundable_support'].notna() | data['nonrefundable_support'].notna()]
average_rating_with_support = movies_with_support['ratings'].mean()
print(f"Средний рейтинг фильмов с государственной поддержкой: {average_rating_with_support:.2f}")
# Out:
# Средний рейтинг фильмов с государственной поддержкой: 6.04

# %%
import warnings

# Суммарная поддержка (возвратная + невозвратная)
movies_with_support.loc[:, 'total_support'] = movies_with_support['refundable_support'] + movies_with_support['nonrefundable_support']

# Построим график
plt.figure(figsize=(10, 6))
plt.scatter(movies_with_support['total_support'], movies_with_support['ratings'], color='blue', alpha=0.5)
plt.title('Зависимость рейтинга от суммы государственной поддержки')
plt.xlabel('Сумма государственной поддержки')
plt.ylabel('Рейтинг фильма')
plt.grid(True)
plt.show()

# Выведем статистику для анализа
total_support_stats = movies_with_support['total_support'].describe()
ratings_stats = movies_with_support['ratings'].describe()

print("Статистика по сумме государственной поддержки:")
print(total_support_stats)

print("\nСтатистика по рейтингам фильмов:")
print(ratings_stats)




warnings.filterwarnings("ignore")
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexing.py:1597: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# Статистика по сумме государственной поддержки:
# count         315.00
# mean     59710218.56
# std      73085213.48
# min       3000000.00
# 25%      25250000.00
# 50%      35000000.00
# ...

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkGreen'>👌 Когда выскакивают предупреждения, это означает, что в будущей новой версии библиотеки применяемый метод обработки будет не применим. Если планируем данный код использовать в будущем, то надо разобраться и изменить код. Если он в будущем не понадобится, то можно принудительно запретить вывод предупреждений вставив в ячейку с библиотеками вот такой код: <br></font>
# `import warnings`<br>
# `warnings.filterwarnings("ignore")`

# %%
# Фильмы без государственной поддержки
movies_without_support = data[data['refundable_support'].isna() & data['nonrefundable_support'].isna()]

# Средний рейтинг для фильмов с и без поддержки
average_rating_without_support = movies_without_support['ratings'].mean()

print(f"Средний рейтинг фильмов без государственной поддержки: {average_rating_without_support:.2f}")
# Out:
# Средний рейтинг фильмов без государственной поддержки: 6.51

# %% [markdown]
# **Промежуточный вывод**
#
#
# 	1.	Средний рейтинг фильмов с государственной поддержкой: Фильмы, получившие государственную поддержку, в среднем имеют рейтинг 6.04. Это несколько ниже, чем у фильмов без поддержки, что может указывать на то, что поддержка не всегда ассоциируется с высокими оценками зрителей.
# 	2.	Зависимость рейтинга от суммы поддержки: Визуально наблюдается слабая корреляция между суммой государственной поддержки и рейтингом фильма. Рейтинг фильмов варьируется независимо от того, сколько было выделено средств, что свидетельствует о других факторах, влияющих на восприятие фильма.
# 	3.	Сравнение с фильмами без государственной поддержки: Средний рейтинг фильмов без государственной поддержки составляет 6.51, что выше среднего рейтинга фильмов с поддержкой (6.04). Это подтверждает предположение, что фильмы без государственной поддержки могут быть более успешными с точки зрения зрительской оценки, возможно, из-за большей независимости в выборе проектов и более высоких ожиданий от таких фильмов.
#
# Таким образом, хотя государственная поддержка может быть полезной для реализации фильмов, она не всегда гарантирует успех в глазах зрителей, и существует тенденция, что фильмы без поддержки имеют чуть более высокие оценки.

# %% [markdown]
# **Интересно еще посмотреть, какие жанры получают государственную поддержку.**

# %%
# Анализ жанров фильмов с государственной поддержкой
genre_support = movies_with_support['genres'].value_counts()
print("Жанры фильмов с государственной поддержкой:")
print(genre_support)
# Out:
# Жанры фильмов с государственной поддержкой:
# драма          92
# комедия        68
# мультфильм     26
# мелодрама      14
# триллер        14
# фэнтези        11
# фантастика     10
# ужасы          10
# военный         9
# семейный        7
# приключения     7
# боевик          5
# детектив        5
# мюзикл          4
# история         4
# детский         4
# криминал        3
# биография       3
# спорт           3
# реальное        1
# Name: genres, dtype: int64

# %% [markdown]
# **Наиболее часто встречаются жанры “драма” и “комедия”.**

# %% [markdown]
# ## Промежуточный вывод для раздела "Исследовательский анализ данных", где мы анализировали фильмы, которые получили государственную поддержку.
#
#
# В ходе анализа данных о кинофильмах мы смогли выявить несколько интересных трендов.
#
# 	1.	Количество фильмов в прокате: Мы заметили, что данные о прокате становятся более полными начиная с 2015 года, когда доля фильмов с информацией о сборах заметно увеличивается. К примеру, если в 2010 году таких фильмов было меньше 11%, то в 2015 году этот показатель уже достигал 65%. Это говорит о том, что информация по прокату в последние годы стала более доступной и полной.
#
# 	2.	Сумма сборов по годам: Наблюдения за динамикой сборов показали, что с 2015 года сборы фильмов в прокате значительно выросли. В 2010 году общая сумма сборов составила чуть больше полумиллиарда рублей, а в 2015 году этот показатель уже превышал 40 миллиардов рублей. Интересно, что 2016 и 2017 годы показали почти одинаковые сборы, с небольшим ростом в 2018 году.
#
# 	3.	Возрастные ограничения и сборы: По данным за 2015–2019 годы, фильмы с возрастным ограничением "16+" в среднем собрали больше всех, а наименьшие сборы показали фильмы с категорией «0+» (для любой зрительской аудитории). В то же время, структура доходов по возрастным категориям остаётся стабильной на протяжении нескольких лет. Важно отметить, что фильмы с возрастным ограничением «12+» имели самый большой процент сборов в 2015 году.
#
# 	4.	Государственная поддержка: Средний бюджет фильмов с государственной поддержкой составил около 134 миллионов рублей, что указывает на то, что эти проекты, как правило, имеют более высокие бюджеты, чем фильмы без поддержки. Однако, несмотря на большие инвестиции, окупаемость таких фильмов оставалась на уровне 25%, что говорит о том, что многие из них не приносили прибыль. Интересно, что фильмы с государственной поддержкой в среднем получают чуть более низкие оценки зрителей, чем фильмы без поддержки, что может быть связано с различными факторами производства и продвижения.
#
# 	5.	Жанры фильмов с государственной поддержкой: В категории фильмов с государственной поддержкой наиболее популярными жанрами стали драма и комедия. Это говорит о том, что такие жанры пользуются наибольшим интересом у государственной поддержки, возможно, из-за их массовости и привлекательности для широкой аудитории.
#
# В целом, данные показывают, что хотя государственная поддержка и большая сумма инвестиций могут быть полезными для масштабных проектов, успех фильма зависит от множества факторов, таких как жанр, маркетинг и зрительский интерес.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Каждый раздел исследования должен заканчиваться промежуточным выводом.</font>

# %% [markdown]
# ### Шаг 5. Напишите общий вывод

# %% [markdown]
# # Общий вывод для проекта
#
# В ходе выполнения проекта, который охватывает обработку и исследовательский анализ данных о кинофильмах с 2010 по 2019 годы, были достигнуты несколько ключевых выводов, которые могут быть полезны для дальнейших исследований, а также для практического применения в области киноиндустрии.
#
# **1. Обработка данных**
#
# В процессе обработки данных было предпринято несколько шагов, направленных на улучшение качества данных и унификацию их представления:
#
# - **Категориальные данные:** В столбце `type` были удалены лишние пробелы, что значительно уменьшило количество уникальных значений и повысило консистентность данных. В столбце `production_country` были приведены разделители стран, что также способствовало улучшению унификации. Столбец `genres` был упрощён путём сохранения только первого жанра для каждого фильма, что позволило сосредоточиться на наиболее популярных жанрах и упростило дальнейший анализ.
#
# - **Количественные данные:** Были выявлены выбросы в столбцах `nonrefundable_support`, `refundable_support`, `budget` и `box_office`. Эти выбросы не оказали значительного влияния на общий анализ, но они были учтены. Например, выбросы в столбце `nonrefundable_support` можно объяснить крупными и долгосрочными проектами, а выбросы в `refundable_support` связаны с исключительными случаями. Несмотря на это, данные были очищены и приведены к удобному для анализа виду, что повысило точность выводов.
#
# - **Прочее:** Дополнительно были добавлены промежуточные столбцы, которые облегчают дальнейший анализ и выводы. В результате обработки данные стали более чистыми и унифицированными, что позволило проводить более точные и эффективные исследования.
#
# **2. Исследовательский анализ данных**
#
#
#
# Ключевые выводы:
#
# - **Количество фильмов по годам:** Количество фильмов с данными о сборах значительно увеличивалось начиная с 2015 года. Особенно заметен рост в 2015 году, когда количество фильмов с доступной информацией о сборах превысило 400, а в 2019 году достигло более 500. Однако доля таких фильмов оставалась ниже 50%, что указывает на неполные данные по сбору большинства картин.
#
# - **Динамика сборов по годам:** В 2015–2016 годах суммарные сборы по годам показали стабильный рост, а в 2019 году общая сумма сборов в прокате значительно превысила 30 миллиардов рублей. Медианные значения сборов, однако, оставались более стабильными или росли медленно, что свидетельствует о высокой конкуренции в киноиндустрии, где количество фильмов с меньшими сборами увеличивалось, но всё же компенсировалось аномально успешными картинами.
#
# - **Возрастные ограничения и влияние на сборы:** Фильмы с возрастным ограничением «16+» собрали наибольшую сумму, что связано с широкой аудиторией. В то время как фильмы с категорией «0+» (для всей аудитории) значительно отставали в сборах, что, в основном, объясняется мультфильмами и детскими фильмами. В 2015 году категория «12+» показала наибольший процент сборов, но её доля со временем снизилась, что также может быть связано с изменениями в предпочтениях зрителей.
#
# **2.3. Государственная поддержка**
#
# - **Бюджет фильмов с государственной поддержкой:** Средний бюджет таких фильмов составил около 134 миллионов рублей, что указывает на то, что они, как правило, имеют более высокие бюджеты, чем фильмы без государственной поддержки. Однако, несмотря на большие инвестиции, окупаемость таких проектов оставалась на уровне 25%. Это может свидетельствовать о том, что большинство фильмов с государственной поддержкой не приносили значительную прибыль.
#
# - **Оценки зрителей:** Интересный вывод заключается в том, что фильмы с государственной поддержкой имеют несколько более низкие оценки зрителей в сравнении с фильмами без такой поддержки. Это может быть связано с различиями в производственных и маркетинговых подходах, а также с особенностями жанров и тематик, которые получают государственное финансирование.
#
# - **Жанры фильмов с государственной поддержкой:** В фильмах с государственной поддержкой преобладают жанры драмы и комедии, а также их комбинации, такие как «комедия, мелодрама» и «драма, мелодрама». Это может указывать на то, что такие жанры пользуются наибольшим интересом у государственной поддержки, возможно, из-за их массовости и способности привлекать широкую аудиторию.
#
# **2.4. Тренды по жанрам**
#
# - **Популярные жанры:** Для фильмов с государственной поддержкой наиболее распространёнными жанрами являются драма и комедия. Это также указывает на стремление государственной поддержки к финансированию массовых, более доступных фильмов, которые могут привлечь более широкую аудиторию.
#
#
# **Проект позволил выявить несколько ключевых трендов и закономерностей, которые оказывают влияние на развитие киноиндустрии, в том числе:**
#
# - Киноиндустрия демонстрирует значительный рост с 2015 года, что выражается в увеличении как числа фильмов, так и сумм сборов.
# - Информация о прокате становится более полной и доступной с каждым годом, что позволяет более точно оценить успех картин.
# - Хотя государственная поддержка фильмов помогает им иметь большие бюджеты, успешность таких проектов не всегда оправдывает инвестиции, и фильмы с государственной поддержкой в среднем имеют более низкие зрительские оценки.
# - Возрастные ограничения оказывают значительное влияние на кассовые сборы, где фильмы с возрастным ограничением «16+» показывают наибольшие сборы.
# - Для большинства проектов успех фильма зависит от множества факторов, включая жанр, маркетинг и аудиторию, на которую фильм ориентирован.
#
# Таким образом, проведённый анализ предоставил более полную картину развития киноиндустрии в России, а также указал на важность разных факторов в формировании успеха фильмов.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, правильно.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Вывод должен обобщать весь проект, включая раздел анализа и предобработки данных, и кратко суммировать промежуточные выводы разделов всего исследования.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Заключительный комментарий ревьюера</b></font><br><br>
# <font color='DarkGreen'>👌 Андрей, проект отлично структурирован и проработан.<br>Так держать и дальше!<br></font>
# <font color='Red'>🛠 Что нужно, что бы сделать проект лучше:</font><br>
# <font color='Red'>🛠 Необходимо сделать описание проекта. Проверить неявные (неполные) дубликаты. Доделать раздел анализа колонок с категориальными данными, сформулировать общую проблему. Доделать раздел анализа колонок с количественными данными. Сделать выводы по разделу предобработки данных. Графики и диаграммы необходимо оформить подписями осей и названием графика/диаграммы на русском языке. Переделать анализ выхода фильмов в прокат. Сделать анализ и вывод по отличию средней и медианой суммы сбора. Написать выводы по разделу исследовательского анализа данных. Написать выводы по разделу анализа фильмов с господдержкой. Сделать развернутый общий вывод проекта.<br>После исправления ошибок следует проверить и при необходимости откорректировать выводы анализа.</font><br>
# <font color='DarkMagenta'>👉 При исправлении ошибок и недочетов будут приобретены дополнительный опыт и навыки!</font><br>
# <font color='DarkGreen'>👌 Жду окончательный вариант! Успехов.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Заключительный комментарий ревьюера 2</b></font><br><br>
# <font color='DarkGreen'>👌 Андрей, увы, остались еще ошибки.<br></font>
# <font color='Red'>🛠 Что нужно доделать:</font><br>
# <font color='Red'>🛠 Исправить удаление дубликатов в названии фильма. Графики и диаграммы необходимо оформить подписями осей и названием графика/диаграммы на русском языке.<br>Надо будет проверить выводы,  при необходимости  откорректировать.</font><br>
# <font color='DarkGreen'>👌 Жду исправленный вариант! Успехов.</font>

# %% [markdown]
# <b>Комментарий студента</b><br>
#
# Привет, Олег!
#
# С интересом ознакомился с обратной связью. Я обязательно все еще раз пересмотрю, так как из-за срока стараюсь поправить глобальные(красные) ошибки.
#
# Спасибо за разбор моих недочетов и обратную связь.
#
# С ув. Андрей

# %% [markdown]
# <font color='DarkBlue'><b>Заключительный комментарий ревьюера 3</b></font><br><br>
# <font color='DarkGreen'>👌 Привет, Андрей! Удалось справиться со всеми заданиями в проекте. Молодец! 😄 Спасибо за работу!<br>
# Входе выполнения проекта научились анализировать первичные данные и проводить обработку датасета. Провели самостоятельный исследовательский анализ. Хочу обратить внимание на качественное оформление графиков и диаграмм, в реальном проекте на их основе затем делается презентация проекта.</font><br>
# <font color='DarkGreen'>👌 Теперь, вперед за новыми знаниями и навыками! Удачи! 😉</font>
# ![image.png](attachment:image.png)
